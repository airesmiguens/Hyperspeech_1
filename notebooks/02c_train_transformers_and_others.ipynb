# %% [markdown]
# # 02c_train_transformers_and_others
# Trains transformer-style and heavier optional baselines.

# %%
ENABLED_MODELS = ['saint', 'ft_transformer', 'tabtransformer', 'dcnv2', 'node', 'carte']
print(ENABLED_MODELS)
